# %% [markdown]
# <a href="https://colab.research.google.com/github/hizikang/road-object-detection/blob/main/01_%E1%84%83%E1%85%A6%E1%84%8B%E1%85%B5%E1%84%90%E1%85%A5%E1%84%89%E1%85%A6%E1%86%BA_%E1%84%80%E1%85%AE%E1%84%8E%E1%85%AE%E1%86%A8_%E1%84%8F%E1%85%A9%E1%84%83%E1%85%B3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0. 객체탐지(b-box) 모델을 조사
# - 조사한 모델이 예상 성능 요구 사항을 충족시킬 수 있는지 확인해주세요. 확인한 내용을 **PPT 1장~3장**으로 정리해서 제출해주세요.
# - 모델의 라이센스, 오픈 모델의 성능을 파악해서 왜 해당 모델을 선택했는지 작성이 되어야합니다.
# - 업무요청 가이드에서는 yolov5 모델을 baseline모델로 사용하라고 되어있지만, 다른 b-box 모델을 조사했을 때 더 좋은 성능의 모델이 있다면 그 모델로 진행해도 좋습니다.

# %% [markdown]
# # 데이터셋 구축
# - 아래의 코드 가이드를 참고해서 데이터셋 구축하는 코드를 작성해주세요
# - 완료된 데이터셋 구축 코드는 **.ipynb 파일을 다운해서 제출**해주세요.

# %% [markdown]
# # 1. Mount google drive
# - 코랩을 활용할 경우, 구글 드라이브에 있는 데이터를 사용하기 위해서 마운트 작업이 필요합니다.
# - 로컬에서 진행할 경우엔 생략해주세요.
# - 로컬에서 진행할 경우엔 conda를 활용하여 가상환경을 세팅해주세요.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 2. Import Library
# - 코드에 사용되는 파이썬 라이브러리를 불러옵니다.

# %%
import os
import cv2
import glob
import shutil
import warnings
import matplotlib.pyplot as plt

from tqdm.auto import tqdm       # 작업 진행 속도를 보는데 유용한 라이브러리입니다.
from sklearn.model_selection import train_test_split

# %%
# warning 무시 코드
warnings.filterwarnings(action='ignore')

# %%
# 현재 실행 파일 경로 확인
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# # 3. 데이터셋 준비
# - 데이콘의 데이터셋은 차종으로 라벨링 되어 있는데, 우리는 차 종류를 객체탐지하는 것이 아닌 "차"를 객체탐지하는 것이 목표입니다.
# - 차 종류로 라벨링 된 text파일 데이터를 수정해야합니다.

# %%
# 기존에 존재하던 데이터셋 폴더 경로 정의
origin_dir = '/content/drive/MyDrive/comento/data'

# 원본 라벨파일(.txt) 불러오기
origin_label = f'{origin_dir}/*.txt'
label_txts = glob.glob(origin_label)

print('라벨파일(.txt) 개수 : ',len(label_txts))
# Out:
# 라벨파일(.txt) 개수 :  1995

# %%
# 수정된 라벨을 저장하는 폴더 경로 정의
edit_label_dir = '/content/drive/MyDrive/comento/data/label_data'

# 수정된 라벨링 데이터 저장 폴더를 생성
if not os.path.exists(edit_label_dir):
    os.mkdir(edit_label_dir)

# %% [markdown]
# # 4. Yolo 모델링을 위한 라벨링 데이터 수정
# - 모든 데이터의 라벨을 "car"로 변경해야합니다.
# - 기존 데이터셋의 Labelme 형태를 yolo format을 따라 라벨링 파일을 변경해야합니다.
# - 참고 자료: https://docs.ultralytics.com/datasets/detect/#ultralytics-yolo-format
#
#
# ### 코드 설계 참고
# - 코드를 작성하기 전에 구현하고자하는 로직을 텍스트로 설계해보는 연습도 많이 하면 좋을 것 같습니다.
# 1. 기존의 모든 라벨 데이터를 읽기모드로 불러와서 반복문으로 데이터 파일을 하나씩 열어줍니다.
# 2. 1번에서 불러온 라벨데이터(.txt)는 Labelme 형태로 <classId, x1, y1, x2, y2, x3, y3, x4, y4>에 맞게 값을 따로 정의해줍니다.
#   - 참고 : strip().split(' ') 라이브러리 활용 가능
# 3. 모든 데이터의 라벨을 "car" 하나로만 변경해야하므로, classId는 0으로 변경해주세요
# 4. 2번에서 불러온 좌표값들을 활용하여 yolo 라벨 형태에 맞게 중심좌표와 너비/높이를 계산해줍니다.
# 5. 수정된 라벨을 새로운 파일로 저장해줍니다. (라벨 파일명은 매칭되는 이미지파일명과 동일해야합니다.)

# %%
import os
import glob

origin_dir = '/content/drive/MyDrive/comento/data'
origin_label = f'{origin_dir}/*.txt'
label_txts = glob.glob(origin_label)

print('라벨파일(.txt) 개수 : ', len(label_txts))

# 저장 경로
edit_label_dir = '/content/drive/MyDrive/comento/data/label_data'
if not os.path.exists(edit_label_dir):
    os.mkdir(edit_label_dir)

# 이미지 크기 (임시 고정값 사용. 필요시 이미지에서 추출)
img_width = 1280
img_height = 720

# YOLO 변환 함수
def convert_to_yolo_bbox(x_list, y_list, img_w, img_h):
    xmin, xmax = min(x_list), max(x_list)
    ymin, ymax = min(y_list), max(y_list)

    x_center = ((xmin + xmax) / 2) / img_w
    y_center = ((ymin + ymax) / 2) / img_h
    width = (xmax - xmin) / img_w
    height = (ymax - ymin) / img_h

    return round(x_center, 6), round(y_center, 6), round(width, 6), round(height, 6)

# 모든 라벨 파일 변환
for label_path in label_txts:
    with open(label_path, 'r') as f:
        lines = f.readlines()

    new_lines = []
    for line in lines:
        parts = line.strip().split(' ')
        if len(parts) != 9:
            continue

        coords = list(map(float, parts[1:]))  # classId 무시
        x_list = coords[::2]  # x1, x2, x3, x4
        y_list = coords[1::2]  # y1, y2, y3, y4

        x_c, y_c, w, h = convert_to_yolo_bbox(x_list, y_list, img_width, img_height)
        yolo_line = f"0 {x_c} {y_c} {w} {h}\n"
        new_lines.append(yolo_line)

    # 결과 저장
    file_name = os.path.basename(label_path)
    save_path = os.path.join(edit_label_dir, file_name)
    with open(save_path, 'w') as f:
        f.writelines(new_lines)

print("모든 라벨이 YOLO 형식으로 변환 완료")
# Out:
# 라벨파일(.txt) 개수 :  1995
# 모든 라벨이 YOLO 형식으로 변환 완료

# %% [markdown]
# # 5. 라벨이 제대로 수정되었는지 확인하기
# - 아래 함수를 통해 라벨이 제대로 수정되었는지 시각화해서 확인해주세요.
# - 항상 작업을 완료후에는 결과를 확인하면서 이슈가 없는지 파악해야합니다.

# %%
from PIL import Image

def draw_boxes_on_image(image_path : str, annotation_path : str,
                        img_width : int, img_height : int):
    ''' 이미지와 바운딩 박스를 그리는 함수
    Args:
        image_path (str): 이미지 파일 경로
        annotation_path (str): 라벨 파일 경로 (.txt)
        img_width (int): 이미지의 너비
        img_height (int): 이미지의 높이
    Returns:
        show image: 이미지와 바운딩 박스가 그려진 이미지
    '''

    # 이미지 불러오기
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # txt 파일에서 Class ID와 Bounding Box 정보 읽기
    with open(annotation_path, 'r') as file:
        lines = file.readlines()

    for line in lines:
        values = list(map(float, line.strip().split(' ')))
        class_id = int(values[0])

        # YOLO 형식의 좌표를 원래 이미지 크기에 맞게 변환
        x_center = values[1] * img_width
        y_center = values[2] * img_height
        box_width = values[3] * img_width
        box_height = values[4] * img_height

        # 좌표 계산
        x_min = int(round(x_center - (box_width / 2)))
        y_min = int(round(y_center - (box_height / 2)))
        x_max = int(round(x_center + (box_width / 2)))
        y_max = int(round(y_center + (box_height / 2)))

        # 이미지에 바운딩 박스 그리기
        cv2.rectangle(image, (x_min, y_min), (x_max, y_max), (255, 0, 0), 2)
        cv2.putText(image, str(class_id), (x_min, y_min - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

    # 이미지와 바운딩 박스 출력
    plt.figure(figsize=(10, 10))
    plt.imshow(image)
    plt.axis('off')  # 축 숨기기
    plt.show()


#### 검증 함수 실행!!
image_file = os.path.join(origin_dir, 'syn_00000.png')
annotation_file = os.path.join(edit_label_dir, 'syn_00000.txt')
img_width, img_height = Image.open(image_file).size

draw_boxes_on_image(image_file, annotation_file, img_width, img_height)

# %% [markdown]
# # 6. train/valid/test set 분리
# - 간단한 데이터셋 통계량 확인하고, 데이터셋 비율을 정해줍니다.
#   - 차량 데이터 총 개수 확인 (참고 : glob 모듈 사용)
# - 학습/검증/테스트셋 분리
#   - train_test_split 라이브러리를 활용하여 test_size 인자로 데이터셋 비율을 조절할 수 있습니다. (train_test_split라이브러리는 데이터셋을 분리하는데에 많이 사용되고 있습니다.)
#   - trainset : validset : testset  = 6 : 2 : 2

# %%
# 학습/검증/테스트셋 분리
from sklearn.model_selection import train_test_split
import glob
import os

label_dir = '/content/drive/MyDrive/comento/data/label_data'
label_paths = sorted(glob.glob(os.path.join(label_dir, '*.txt')))

# 총 차량 라벨 데이터 개수 확인
print(f"차량 데이터 총 개수: {len(label_paths)}")

# 1차 분리: 80% train+val / 20% test
train_val, test_list = train_test_split(label_paths, test_size=0.2, random_state=42)

# 2차 분리: 80% 중 25%를 val로 → 전체 중 20%
train_list, val_list = train_test_split(train_val, test_size=0.25, random_state=42)

print(f"학습용 (train): {len(train_list)}개")
print(f"검증용 (val): {len(val_list)}개")
print(f"테스트용 (test): {len(test_list)}개")
# Out:
# 차량 데이터 총 개수: 1995
# 학습용 (train): 1197개
# 검증용 (val): 399개
# 테스트용 (test): 399개

# %% [markdown]
# # 7. 학습용 train/valid/test 데이터셋 폴더 생성
#
# - 위에서 분리한 train/valid/testset을 옮겨둘 폴더를 생성하고, 파일을 복사해서 옮겨줍니다.
# - 아래의 폴더 구조로 만들어주세요.
#
# ```
# └── datasets /
#     ├── images /
#         ├── train /
#             ├── 1.png
#             ├── 2.png
#         ├── val /
#             ├── 3.png
#             ├── 4.png
#         ├── test /
#             ├── 5.png
#             ├── 6.png
#     ├── labels /
#         ├── train /
#             ├── 1.txt
#             ├── 2.txt
#         ├── val /
#             ├── 3.txt
#             ├── 4.txt
#         ├── test /
#             ├── 5.txt
#             ├── 6.txt
# ```
#
# - 데이터를 저장하고자 하는 곳으로 이동 (참고 : shutil.copy 라이브러리 사용)
# - 참고 자료: https://docs.ultralytics.com/datasets/detect/#ultralytics-yolo-format
# - 구글드라이브의 용량이 부족하다면 데이터를 조금 더 삭제해서 줄여도 괜찮습니다.

# %%
import os
import glob
import shutil
from sklearn.model_selection import train_test_split

# 경로
origin_image_dir = '/content/drive/MyDrive/comento/data'  # .png 이미지 포함
origin_label_dir = '/content/drive/MyDrive/comento/data/label_data'  # YOLO 라벨만
output_dir = '/content/drive/MyDrive/comento/datasets'  # 최종 저장

# YOLO 라벨 기준으로 (image, label) 쌍 수집
label_paths = sorted(glob.glob(os.path.join(origin_label_dir, '*.txt')))
dataset = []

for label_path in label_paths:
    base_name = os.path.basename(label_path).replace('.txt', '.png')
    image_path = os.path.join(origin_image_dir, base_name)

    if os.path.exists(image_path):
        dataset.append((image_path, label_path))
    else:
        print(f"이미지 없음: {base_name}")

print(f"유효한 데이터 수: {len(dataset)}")

# 6:2:2 분할
train_val, test = train_test_split(dataset, test_size=0.2, random_state=42)
train, val = train_test_split(train_val, test_size=0.25, random_state=42)

# 폴더 생성
for split in ['train', 'val', 'test']:
    os.makedirs(os.path.join(output_dir, 'images', split), exist_ok=True)
    os.makedirs(os.path.join(output_dir, 'labels', split), exist_ok=True)

# 복사 함수
def copy_files(pairs, split):
    for img_path, label_path in pairs:
        img_name = os.path.basename(img_path)
        label_name = os.path.basename(label_path)

        # 대상 경로
        dst_img = os.path.join(output_dir, 'images', split, img_name)
        dst_label = os.path.join(output_dir, 'labels', split, label_name)

        shutil.copy(img_path, dst_img)
        shutil.copy(label_path, dst_label)

# 실행
copy_files(train, 'train')
copy_files(val, 'val')
copy_files(test, 'test')

print("데이터셋 구축 완료 YOLO 학습 구조로 정리되었습니다.")
# Out:
# 이미지 없음: syn_00008.png
# 이미지 없음: syn_00009.png
# 이미지 없음: syn_00018.png
# 이미지 없음: syn_00019.png
# 이미지 없음: syn_00020.png
# 이미지 없음: syn_00021.png
# 이미지 없음: syn_00022.png
# 이미지 없음: syn_00023.png
# 이미지 없음: syn_00024.png
# 이미지 없음: syn_00025.png
# 이미지 없음: syn_00026.png
# 이미지 없음: syn_00027.png
# 이미지 없음: syn_00030.png
# 이미지 없음: syn_00031.png
# 이미지 없음: syn_00032.png
# 이미지 없음: syn_00033.png
# 이미지 없음: syn_00034.png
# 이미지 없음: syn_00035.png
# 이미지 없음: syn_00036.png
# 이미지 없음: syn_00037.png
# 이미지 없음: syn_00040.png
# 이미지 없음: syn_00041.png
# 이미지 없음: syn_00042.png
# 이미지 없음: syn_00043.png
# 이미지 없음: syn_00044.png
# 이미지 없음: syn_00045.png
# 이미지 없음: syn_00046.png
# 이미지 없음: syn_00047.png
# 이미지 없음: syn_00050.png
# 이미지 없음: syn_00051.png
# 이미지 없음: syn_00052.png
# 이미지 없음: syn_00053.png
# 이미지 없음: syn_00054.png
# 이미지 없음: syn_00055.png
# 이미지 없음: syn_00056.png
# 이미지 없음: syn_00057.png
# 이미지 없음: syn_00068.png
# 이미지 없음: syn_00069.png
# 이미지 없음: syn_00078.png
# 이미지 없음: syn_00079.png
# 이미지 없음: syn_00080.png
# 이미지 없음: syn_00081.png
# 이미지 없음: syn_00082.png
# 이미지 없음: syn_00083.png
# 이미지 없음: syn_00084.png
# 이미지 없음: syn_00085.png
# 이미지 없음: syn_00906.png
# 이미지 없음: syn_00907.png
# 이미지 없음: syn_00910.png
# 이미지 없음: syn_00911.png
# 이미지 없음: syn_00912.png
# 이미지 없음: syn_00913.png
# 이미지 없음: syn_00914.png
# 이미지 없음: syn_00915.png
# 이미지 없음: syn_00916.png
# 이미지 없음: syn_00917.png
# 이미지 없음: syn_00928.png
# 이미지 없음: syn_00929.png
# 이미지 없음: syn_00938.png
# 이미지 없음: syn_00939.png
# 이미지 없음: syn_00948.png
# 이미지 없음: syn_00949.png
# 이미지 없음: syn_00958.png
# 이미지 없음: syn_00959.png
# 이미지 없음: syn_00960.png
# 이미지 없음: syn_00961.png
# 이미지 없음: syn_00962.png
# 이미지 없음: syn_00963.png
# 이미지 없음: syn_00964.png
# 이미지 없음: syn_00965.png
# 이미지 없음: syn_00966.png
# 이미지 없음: syn_00967.png
# 이미지 없음: syn_00970.png
# 이미지 없음: syn_00971.png
# 이미지 없음: syn_00972.png
# 이미지 없음: syn_00973.png
# 이미지 없음: syn_00974.png
# 이미지 없음: syn_00975.png
# 이미지 없음: syn_00976.png
# 이미지 없음: syn_00977.png
# 이미지 없음: syn_00988.png
# 이미지 없음: syn_00989.png
# 이미지 없음: syn_00993.png
# 이미지 없음: syn_00998.png
# 이미지 없음: syn_00999.png
# 이미지 없음: syn_01000.png
# 이미지 없음: syn_01001.png
# 이미지 없음: syn_01002.png
# 이미지 없음: syn_01003.png
# 이미지 없음: syn_01004.png
# 이미지 없음: syn_01005.png
# 이미지 없음: syn_01006.png
# 이미지 없음: syn_01007.png
# 이미지 없음: syn_01010.png
# 이미지 없음: syn_01011.png
# 이미지 없음: syn_01012.png
# 이미지 없음: syn_01013.png
# 이미지 없음: syn_01014.png
# 이미지 없음: syn_01015.png
# 이미지 없음: syn_01016.png
# 이미지 없음: syn_01017.png
# 이미지 없음: syn_01028.png
# 이미지 없음: syn_01029.png
# 이미지 없음: syn_01038.png
# 이미지 없음: syn_01039.png
# 이미지 없음: syn_01048.png
# 이미지 없음: syn_01049.png
# 이미지 없음: syn_01058.png
# 이미지 없음: syn_01059.png
# 이미지 없음: syn_01060.png
# 이미지 없음: syn_01061.png
# 이미지 없음: syn_01062.png
# 이미지 없음: syn_01063.png
# 이미지 없음: syn_01064.png
# 이미지 없음: syn_01065.png
# 이미지 없음: syn_01066.png
# 이미지 없음: syn_01067.png
# 이미지 없음: syn_01070.png
# 이미지 없음: syn_01071.png
# 이미지 없음: syn_01072.png
# 이미지 없음: syn_01073.png
# 이미지 없음: syn_01074.png
# 이미지 없음: syn_01075.png
# 이미지 없음: syn_01076.png
# 이미지 없음: syn_01077.png
# 이미지 없음: syn_01088.png
# 이미지 없음: syn_01089.png
# 이미지 없음: syn_01098.png
# 이미지 없음: syn_01099.png
# 이미지 없음: syn_01100.png
# 이미지 없음: syn_01101.png
# 이미지 없음: syn_01102.png
# 이미지 없음: syn_01103.png
# 이미지 없음: syn_01104.png
# 이미지 없음: syn_01105.png
# 이미지 없음: syn_01106.png
# 이미지 없음: syn_01107.png
# 이미지 없음: syn_01110.png
# 이미지 없음: syn_01111.png
# 이미지 없음: syn_01112.png
# 이미지 없음: syn_01113.png
# 이미지 없음: syn_01114.png
# 이미지 없음: syn_01115.png
# 이미지 없음: syn_01116.png
# 이미지 없음: syn_01117.png
# 이미지 없음: syn_01128.png
# 이미지 없음: syn_01129.png
# 이미지 없음: syn_01138.png
# 이미지 없음: syn_01139.png
# 이미지 없음: syn_01148.png
# 이미지 없음: syn_01149.png
# 이미지 없음: syn_01158.png
# 이미지 없음: syn_01159.png
# 이미지 없음: syn_01160.png
# 이미지 없음: syn_01161.png
# 이미지 없음: syn_01162.png
# 이미지 없음: syn_01163.png
# 이미지 없음: syn_01164.png
# 이미지 없음: syn_01165.png
# 이미지 없음: syn_01166.png
# 이미지 없음: syn_01167.png
# 이미지 없음: syn_01170.png
# 이미지 없음: syn_01171.png
# 이미지 없음: syn_01172.png
# 이미지 없음: syn_01173.png
# 이미지 없음: syn_01174.png
# 이미지 없음: syn_01175.png
# 이미지 없음: syn_01176.png
# 이미지 없음: syn_01177.png
# 이미지 없음: syn_01188.png
# 이미지 없음: syn_01189.png
# 이미지 없음: syn_01198.png
# 이미지 없음: syn_01199.png
# 이미지 없음: syn_01200.png
# 이미지 없음: syn_01201.png
# 이미지 없음: syn_01202.png
# 이미지 없음: syn_01203.png
# 이미지 없음: syn_01204.png
# 이미지 없음: syn_01205.png
# 이미지 없음: syn_01206.png
# 이미지 없음: syn_01207.png
# 이미지 없음: syn_01210.png
# 이미지 없음: syn_01211.png
# 이미지 없음: syn_01212.png
# 이미지 없음: syn_01213.png
# 이미지 없음: syn_01214.png
# 이미지 없음: syn_01215.png
# 이미지 없음: syn_01216.png
# 이미지 없음: syn_01217.png
# 이미지 없음: syn_01228.png
# 이미지 없음: syn_01229.png
# 이미지 없음: syn_01238.png
# 이미지 없음: syn_01239.png
# 이미지 없음: syn_01248.png
# 이미지 없음: syn_01249.png
# 이미지 없음: syn_01258.png
# 이미지 없음: syn_01259.png
# 이미지 없음: syn_01260.png
# 이미지 없음: syn_01261.png
# 이미지 없음: syn_01262.png
# 이미지 없음: syn_01263.png
# 이미지 없음: syn_01264.png
# 이미지 없음: syn_01265.png
# 이미지 없음: syn_01266.png
# 이미지 없음: syn_01267.png
# 이미지 없음: syn_01270.png
# 이미지 없음: syn_01271.png
# 이미지 없음: syn_01272.png
# 이미지 없음: syn_01273.png
# 이미지 없음: syn_01274.png
# 이미지 없음: syn_01275.png
# 이미지 없음: syn_01276.png
# 이미지 없음: syn_01277.png
# 이미지 없음: syn_01288.png
# 이미지 없음: syn_01289.png
# 이미지 없음: syn_01298.png
# 이미지 없음: syn_01299.png
# 이미지 없음: syn_01300.png
# 이미지 없음: syn_01301.png
# 이미지 없음: syn_01302.png
# 이미지 없음: syn_01303.png
# 이미지 없음: syn_01304.png
# 이미지 없음: syn_01305.png
# 이미지 없음: syn_01306.png
# 이미지 없음: syn_01307.png
# 이미지 없음: syn_01310.png
# 이미지 없음: syn_01311.png
# 이미지 없음: syn_01312.png
# 이미지 없음: syn_01313.png
# 이미지 없음: syn_01314.png
# 이미지 없음: syn_01315.png
# 이미지 없음: syn_01316.png
# 이미지 없음: syn_01317.png
# 이미지 없음: syn_01328.png
# 이미지 없음: syn_01329.png
# 이미지 없음: syn_01333.png
# 이미지 없음: syn_01338.png
# 이미지 없음: syn_01339.png
# 이미지 없음: syn_01348.png
# 이미지 없음: syn_01349.png
# 이미지 없음: syn_01358.png
# 이미지 없음: syn_01359.png
# 이미지 없음: syn_01360.png
# 이미지 없음: syn_01361.png
# 이미지 없음: syn_01362.png
# 이미지 없음: syn_01363.png
# 이미지 없음: syn_01364.png
# 이미지 없음: syn_01365.png
# 이미지 없음: syn_01366.png
# 이미지 없음: syn_01367.png
# 이미지 없음: syn_01370.png
# 이미지 없음: syn_01371.png
# 이미지 없음: syn_01372.png
# 이미지 없음: syn_01373.png
# 이미지 없음: syn_01374.png
# 이미지 없음: syn_01375.png
# 이미지 없음: syn_01376.png
# 이미지 없음: syn_01377.png
# 이미지 없음: syn_01388.png
# 이미지 없음: syn_01389.png
# 이미지 없음: syn_01398.png
# 이미지 없음: syn_01399.png
# 이미지 없음: syn_01400.png
# 이미지 없음: syn_01401.png
# 이미지 없음: syn_01402.png
# 이미지 없음: syn_01403.png
# 이미지 없음: syn_01404.png
# 이미지 없음: syn_01405.png
# 이미지 없음: syn_01406.png
# 이미지 없음: syn_01407.png
# 이미지 없음: syn_01410.png
# 이미지 없음: syn_01411.png
# 이미지 없음: syn_01412.png
# 이미지 없음: syn_01413.png
# 이미지 없음: syn_01414.png
# 이미지 없음: syn_01415.png
# 이미지 없음: syn_01416.png
# 이미지 없음: syn_01417.png
# 이미지 없음: syn_01428.png
# 이미지 없음: syn_01429.png
# 이미지 없음: syn_01438.png
# 이미지 없음: syn_01439.png
# 이미지 없음: syn_01441.png
# 이미지 없음: syn_01448.png
# 이미지 없음: syn_01449.png
# 이미지 없음: syn_01455.png
# 이미지 없음: syn_01458.png
# 이미지 없음: syn_01459.png
# 이미지 없음: syn_01460.png
# 이미지 없음: syn_01461.png
# 이미지 없음: syn_01462.png
# 이미지 없음: syn_01463.png
# 이미지 없음: syn_01464.png
# 이미지 없음: syn_01465.png
# 이미지 없음: syn_01466.png
# 이미지 없음: syn_01467.png
# 이미지 없음: syn_01470.png
# 이미지 없음: syn_01471.png
# 이미지 없음: syn_01472.png
# 이미지 없음: syn_01473.png
# 이미지 없음: syn_01474.png
# 이미지 없음: syn_01475.png
# 이미지 없음: syn_01476.png
# 이미지 없음: syn_01477.png
# 이미지 없음: syn_01488.png
# 이미지 없음: syn_01489.png
# 이미지 없음: syn_01498.png
# 이미지 없음: syn_01499.png
# 이미지 없음: syn_01500.png
# 이미지 없음: syn_01501.png
# 이미지 없음: syn_01502.png
# 이미지 없음: syn_01503.png
# 이미지 없음: syn_01504.png
# 이미지 없음: syn_01505.png
# 이미지 없음: syn_01506.png
# 이미지 없음: syn_01507.png
# 이미지 없음: syn_01510.png
# 이미지 없음: syn_01511.png
# 이미지 없음: syn_01512.png
# 이미지 없음: syn_01513.png
# 이미지 없음: syn_01514.png
# 이미지 없음: syn_01515.png
# 이미지 없음: syn_01516.png
# 이미지 없음: syn_01517.png
# 이미지 없음: syn_01528.png
# 이미지 없음: syn_01529.png
# 이미지 없음: syn_01538.png
# 이미지 없음: syn_01539.png
# 이미지 없음: syn_01548.png
# 이미지 없음: syn_01549.png
# 이미지 없음: syn_01558.png
# 이미지 없음: syn_01559.png
# 이미지 없음: syn_01560.png
# 이미지 없음: syn_01561.png
# 이미지 없음: syn_01562.png
# 이미지 없음: syn_01563.png
# 이미지 없음: syn_01564.png
# 이미지 없음: syn_01565.png
# 이미지 없음: syn_01566.png
# 이미지 없음: syn_01567.png
# 이미지 없음: syn_01570.png
# 이미지 없음: syn_01571.png
# 이미지 없음: syn_01572.png
# 이미지 없음: syn_01573.png
# 이미지 없음: syn_01574.png
# 이미지 없음: syn_01575.png
# 이미지 없음: syn_01576.png
# 이미지 없음: syn_01577.png
# 이미지 없음: syn_01588.png
# 이미지 없음: syn_01589.png
# 이미지 없음: syn_01598.png
# 이미지 없음: syn_01599.png
# 이미지 없음: syn_01600.png
# 이미지 없음: syn_01601.png
# 이미지 없음: syn_01602.png
# 이미지 없음: syn_01603.png
# 이미지 없음: syn_01604.png
# 이미지 없음: syn_01605.png
# 이미지 없음: syn_01606.png
# 이미지 없음: syn_01607.png
# 이미지 없음: syn_01610.png
# 이미지 없음: syn_01611.png
# 이미지 없음: syn_01612.png
# 이미지 없음: syn_01613.png
# 이미지 없음: syn_01614.png
# 이미지 없음: syn_01615.png
# 이미지 없음: syn_01616.png
# 이미지 없음: syn_01617.png
# 이미지 없음: syn_01628.png
# 이미지 없음: syn_01629.png
# 이미지 없음: syn_01638.png
# 이미지 없음: syn_01639.png
# 이미지 없음: syn_01648.png
# 이미지 없음: syn_01649.png
# 이미지 없음: syn_01658.png
# 이미지 없음: syn_01659.png
# 이미지 없음: syn_01660.png
# 이미지 없음: syn_01661.png
# 이미지 없음: syn_01662.png
# 이미지 없음: syn_01663.png
# 이미지 없음: syn_01664.png
# 이미지 없음: syn_01665.png
# 이미지 없음: syn_01666.png
# 이미지 없음: syn_01667.png
# 이미지 없음: syn_01670.png
# 이미지 없음: syn_01671.png
# 이미지 없음: syn_01672.png
# 이미지 없음: syn_01673.png
# 이미지 없음: syn_01674.png
# 이미지 없음: syn_01675.png
# 이미지 없음: syn_01676.png
# 이미지 없음: syn_01677.png
# 이미지 없음: syn_01688.png
# 이미지 없음: syn_01689.png
# 이미지 없음: syn_01698.png
# 이미지 없음: syn_01699.png
# 이미지 없음: syn_01700.png
# 이미지 없음: syn_01701.png
# 이미지 없음: syn_01702.png
# 이미지 없음: syn_01703.png
# 이미지 없음: syn_01704.png
# 이미지 없음: syn_01705.png
# 이미지 없음: syn_01706.png
# 이미지 없음: syn_01707.png
# 이미지 없음: syn_01710.png
# 이미지 없음: syn_01711.png
# 이미지 없음: syn_01712.png
# 이미지 없음: syn_01713.png
# 이미지 없음: syn_01714.png
# 이미지 없음: syn_01715.png
# 이미지 없음: syn_01716.png
# 이미지 없음: syn_01717.png
# 이미지 없음: syn_01728.png
# 이미지 없음: syn_01729.png
# 이미지 없음: syn_01738.png
# 이미지 없음: syn_01739.png
# 이미지 없음: syn_01748.png
# 이미지 없음: syn_01749.png
# 이미지 없음: syn_01758.png
# 이미지 없음: syn_01759.png
# 이미지 없음: syn_01760.png
# 이미지 없음: syn_01761.png
# 이미지 없음: syn_01762.png
# 이미지 없음: syn_01763.png
# 이미지 없음: syn_01764.png
# 이미지 없음: syn_01765.png
# 이미지 없음: syn_01766.png
# 이미지 없음: syn_01767.png
# 이미지 없음: syn_01770.png
# 이미지 없음: syn_01771.png
# 이미지 없음: syn_01772.png
# 이미지 없음: syn_01773.png
# 이미지 없음: syn_01774.png
# 이미지 없음: syn_01775.png
# 이미지 없음: syn_01776.png
# 이미지 없음: syn_01777.png
# 이미지 없음: syn_01788.png
# 이미지 없음: syn_01789.png
# 이미지 없음: syn_01798.png
# 이미지 없음: syn_01799.png
# 이미지 없음: syn_01808.png
# 이미지 없음: syn_01809.png
# 이미지 없음: syn_01818.png
# 이미지 없음: syn_01819.png
# 이미지 없음: syn_01820.png
# 이미지 없음: syn_01821.png
# 이미지 없음: syn_01822.png
# 이미지 없음: syn_01823.png
# 이미지 없음: syn_01824.png
# 이미지 없음: syn_01825.png
# 이미지 없음: syn_01826.png
# 이미지 없음: syn_01827.png
# 이미지 없음: syn_01830.png
# 이미지 없음: syn_01831.png
# 이미지 없음: syn_01832.png
# 이미지 없음: syn_01833.png
# 이미지 없음: syn_01834.png
# 이미지 없음: syn_01835.png
# 이미지 없음: syn_01836.png
# 이미지 없음: syn_01837.png
# 이미지 없음: syn_01840.png
# 이미지 없음: syn_01841.png
# 이미지 없음: syn_01842.png
# 이미지 없음: syn_01843.png
# 이미지 없음: syn_01844.png
# 이미지 없음: syn_01845.png
# 이미지 없음: syn_01846.png
# 이미지 없음: syn_01847.png
# 이미지 없음: syn_01850.png
# 이미지 없음: syn_01851.png
# 이미지 없음: syn_01852.png
# 이미지 없음: syn_01853.png
# 이미지 없음: syn_01854.png
# 이미지 없음: syn_01855.png
# 이미지 없음: syn_01856.png
# 이미지 없음: syn_01857.png
# 이미지 없음: syn_01868.png
# 이미지 없음: syn_01869.png
# 이미지 없음: syn_01878.png
# 이미지 없음: syn_01879.png
# 이미지 없음: syn_01880.png
# 이미지 없음: syn_01881.png
# 이미지 없음: syn_01882.png
# 이미지 없음: syn_01883.png
# 이미지 없음: syn_01884.png
# 이미지 없음: syn_01885.png
# 이미지 없음: syn_01886.png
# 이미지 없음: syn_01887.png
# 이미지 없음: syn_01890.png
# 이미지 없음: syn_01891.png
# 이미지 없음: syn_01892.png
# 이미지 없음: syn_01893.png
# 이미지 없음: syn_01894.png
# 이미지 없음: syn_01895.png
# 이미지 없음: syn_01896.png
# 이미지 없음: syn_01897.png
# 이미지 없음: syn_01908.png
# 이미지 없음: syn_01909.png
# 이미지 없음: syn_01918.png
# 이미지 없음: syn_01919.png
# 이미지 없음: syn_01920.png
# 이미지 없음: syn_01921.png
# 이미지 없음: syn_01922.png
# 이미지 없음: syn_01923.png
# 이미지 없음: syn_01924.png
# 이미지 없음: syn_01925.png
# 이미지 없음: syn_01926.png
# 이미지 없음: syn_01927.png
# 이미지 없음: syn_01930.png
# 이미지 없음: syn_01931.png
# 이미지 없음: syn_01932.png
# 이미지 없음: syn_01933.png
# 이미지 없음: syn_01934.png
# 이미지 없음: syn_01935.png
# 이미지 없음: syn_01936.png
# 이미지 없음: syn_01937.png
# 이미지 없음: syn_01940.png
# 이미지 없음: syn_01941.png
# 이미지 없음: syn_01942.png
# 이미지 없음: syn_01943.png
# 이미지 없음: syn_01944.png
# 이미지 없음: syn_01945.png
# 이미지 없음: syn_01946.png
# 이미지 없음: syn_01947.png
# 이미지 없음: syn_01950.png
# 이미지 없음: syn_01951.png
# 이미지 없음: syn_01952.png
# 이미지 없음: syn_01953.png
# 이미지 없음: syn_01954.png
# 이미지 없음: syn_01955.png
# 이미지 없음: syn_01956.png
# 이미지 없음: syn_01957.png
# 이미지 없음: syn_01968.png
# 이미지 없음: syn_01969.png
# 이미지 없음: syn_01978.png
# 이미지 없음: syn_01979.png
# 이미지 없음: syn_01980.png
# 이미지 없음: syn_01981.png
# 이미지 없음: syn_01982.png
# 이미지 없음: syn_01983.png
# 이미지 없음: syn_01984.png
# 이미지 없음: syn_01985.png
# 이미지 없음: syn_01986.png
# 이미지 없음: syn_01987.png
# 이미지 없음: syn_01990.png
# 이미지 없음: syn_01991.png
# 이미지 없음: syn_01992.png
# 이미지 없음: syn_01993.png
# 이미지 없음: syn_01994.png
# 유효한 데이터 수: 994
# 데이터셋 구축 완료 YOLO 학습 구조로 정리되었습니다.

# %% [markdown]
# - 학습에 사용되는 .yaml 파일을 아래 형식에 맞춰서 만들어줍니다.
#
# ```
# names:
# - car
# nc: 1
# path: "dataset_folder_root_path"
# test: "test_image_dataset_folder_path"
# train: "train_image_dataset_folder_path"
# val: "validation_image_dataset_folder_path"
# ```

# %%
# yaml 파일 생성 코드 작성 후 저장
import os
import yaml

# 경로
dataset_root = '/content/drive/MyDrive/comento/datasets'
train_path = os.path.join(dataset_root, 'images/train')
val_path = os.path.join(dataset_root, 'images/val')
test_path = os.path.join(dataset_root, 'images/test')

# YAML 내용
data_yaml = {
    'names': ['car'],
    'nc': 1,
    'path': dataset_root,
    'train': 'images/train',
    'val': 'images/val',
    'test': 'images/test'
}

# 저장 경로
yaml_save_path = os.path.join(dataset_root, 'data.yaml')

# 파일로 저장
with open(yaml_save_path, 'w') as f:
    yaml.dump(data_yaml, f, default_flow_style=False)

print(f"data.yaml 생성 완료: {yaml_save_path}")
# Out:
# data.yaml 생성 완료: /content/drive/MyDrive/comento/datasets/data.yaml

# %%
# 생성한 YAML 파일 읽기
yaml_path = '/content/drive/MyDrive/comento/datasets/data.yaml'

with open(yaml_path, 'r') as f:
    data = yaml.full_load(f)

# 내용 출력
print(data)
# Out:
# {'names': ['car'], 'nc': 1, 'path': '/content/drive/MyDrive/comento/datasets', 'test': 'images/test', 'train': 'images/train', 'val': 'images/val'}
